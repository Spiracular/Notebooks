# %%
# %pylab inline

import numpy as np
import matplotlib as plt
import pandas as pd
import math
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
nba = pd.read_csv(open('Data/nba_2013.csv', 'r'))
nba2 = pd.DataFrame.from_csv(open('Data/nba_2013.csv'))
#They yield slightly different DataFrames! read_csv adds a numbered index, from_csv uses first column as index.

# %%
nba.head()
# Out:
#           player pos  age bref_team_id   g  gs    mp   fg   fga    fg.  \
# 0     Quincy Acy  SF   23          TOT  63   0   847   66   141  0.468
# 1   Steven Adams   C   20          OKC  81  20  1197   93   185  0.503
# 2    Jeff Adrien  PF   27          TOT  53  12   961  143   275  0.520
# 3  Arron Afflalo  SG   28          ORL  73  73  2552  464  1011  0.459
# 4  Alexis Ajinca   C   25          NOP  56  30   951  136   249  0.546
#
#       ...      drb  trb  ast  stl  blk  tov   pf   pts     season  season_end
# 0     ...      144  216   28   23   26   30  122   171  2013-2014        2013
# 1     ...      190  332   43   40   57   71  203   265  2013-2014        2013
# 2     ...      204  306   38   24   36   39  108   362  2013-2014        2013
# 3     ...      230  262  248   35    3  146  136  1330  2013-2014        2013
# 4     ...      183  277   40   23   46   63  187   328  2013-2014        2013
#
# [5 rows x 31 columns]

# %%
nba2.head()
# Out:
#               pos  age bref_team_id   g  gs    mp   fg   fga    fg.  x3p  \
# player
# Quincy Acy     SF   23          TOT  63   0   847   66   141  0.468    4
# Steven Adams    C   20          OKC  81  20  1197   93   185  0.503    0
# Jeff Adrien    PF   27          TOT  53  12   961  143   275  0.520    0
# Arron Afflalo  SG   28          ORL  73  73  2552  464  1011  0.459  128
# Alexis Ajinca   C   25          NOP  56  30   951  136   249  0.546    0
#
#                   ...      drb  trb  ast  stl  blk  tov   pf   pts     season  \
# player            ...
# Quincy Acy        ...      144  216   28   23   26   30  122   171  2013-2014
# Steven Adams      ...      190  332   43   40   57   71  203   265  2013-2014
# Jeff Adrien       ...      204  306   38   24   36   39  108   362  2013-2014
# Arron Afflalo     ...      230  262  248   35    3  146  136  1330  2013-2014
# Alexis Ajinca     ...      183  277   40   23   46   63  187   328  2013-2014
#
# ...

# %%
nba.columns.values
# Out:
# array(['player', 'pos', 'age', 'bref_team_id', 'g', 'gs', 'mp', 'fg',
#        'fga', 'fg.', 'x3p', 'x3pa', 'x3p.', 'x2p', 'x2pa', 'x2p.', 'efg.',
#        'ft', 'fta', 'ft.', 'orb', 'drb', 'trb', 'ast', 'stl', 'blk', 'tov',
#        'pf', 'pts', 'season', 'season_end'], dtype=object)

# %%
def euclidean_distance(row):
    """
    A simple euclidean distance function
    """
    inner_value = 0
    for k in distance_columns:
        inner_value += (row[k] - selected_player[k]) ** 2
    return math.sqrt(inner_value)

# %%
position = nba['pos'].value_counts()
position
# Out:
# SG    109
# SF     99
# PF     96
# C      90
# PG     85
# F       1
# G       1
# dtype: int64

# %%
selected_player = nba[nba["player"] == "LeBron James"].iloc[0]
lebron_distance = nba.apply(euclidean_distance, axis=1)
print lebron_distance
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-8602237cea8b> in <module>()
#       1 selected_player = nba[nba["player"] == "LeBron James"].iloc[0]
# ----> 2 lebron_distance = nba.apply(euclidean_distance, axis=1)
#       3 print lebron_distance
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/core/frame.pyc in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    3716                     if reduce is None:
#    3717                         reduce = True
# -> 3718                     return self._apply_standard(f, axis, reduce=reduce)
#    3719             else:
#    3720                 return self._apply_broadcast(f, axis)
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/core/frame.pyc in _apply_standard(self, func, axis, ignore_failures, reduce)
# ...

# %%
lebron_distance = nba.apply(euclidean_distance, player))
