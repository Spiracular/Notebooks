# %%
# %pylab inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from ipywidgets import *
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
LWCom = pd.DataFrame.from_csv(open('Data/LWCommentsAnalysis.csv'))
#This is the output from Olivia's PCA program with LessWrong comments as input

# %%
LWCom.head(20)
# Out:
#                     0             1                  2              3  \
# 0             espouse  slaughtering          dissipate       economic
# 1         cognitivist        raping     malfunctioning      societies
# 2        subjectivist    rebellious       controllable   generational
# 3         wrongheaded      imprison           concious     hereditary
# 4        contemptuous       bullied           coupling   institutions
# 5           espousing          flee      perturbations        sectors
# 6              humean   desperation          fuzziness    initiatives
# 7       offensiveness        sinful      unanticipated   occupational
# 8   epistemologically      stabbing          gradients    criminality
# 9           emotivism       bullies         observably  institutional
# 10         empiricist        robbed         tolerances        nations
# 11      descriptively       wronged  neurotransmitters     regulatory
# ...

# %%
LWCom.tail(20)
# Out:
#                  0               1            2          3                4  \
# 20888    transport       bitstream      kaufman    rubbing         managing
# 20889      battery      asymptotic         ryan      waits       facilitate
# 20890         kits         mapping        aaron      omake         subskill
# 20891      freezer          udassa   washington    clicked         requests
# 20892         tube     topological   journalist        hat        reviewing
# 20893      heating       formalism         dean       grin         overtime
# 20894      capsule       waterfall  christopher    tripped     incentivized
# 20895   dishwasher      parametric    reporters  refreshed       moderating
# 20896  residential     algorithmic        jimmy       argh       networking
# 20897         rack  axiomatization      patrick   snapping       soliciting
# 20898       gallon      generative        galef    slapped          clients
# ...

# %%
LWCom['7'].head()
# Out:
# 0          pies
# 1    adjectives
# 2          bins
# 3         cater
# 4     designate
# Name: 7, dtype: object
